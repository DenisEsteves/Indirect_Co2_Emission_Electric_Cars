# %%
from tkinter import *
from PIL import ImageTk, Image
from tkinter import font
from tkinter import ttk
import tkinter as tk
from pandastable import Table, TableModel
from IPython.display import display
import pandas as pd

# %%
ventana=Tk()
ventana.title("Co2 car emission")
ventana.geometry("1200x600")
ventana.configure(background= "#10222F")
habit_list=[]
country_picks=[]
car_picks=[]

coal_prod = 1002.439
nuclear_prod = 0.2*1002.439 
natural_gas_prod = 417.305
renewable_prod = 0.2*1002.439 
hydroelectric_prod = 0.2*1002.439 
oil_prod = 957.0799

Helvfont54 = font.Font(family="Trebuchet", size=54, weight="bold")
entryi = Text(ventana, font= Helvfont54, background="#10222F",height=1, width=33,foreground="#c0c0c0",bd=0)
entryi.insert(tk.INSERT, "Co2 emission calculator")
entryi.place(x=200, y=60)
Helvfont16 = font.Font(family="Trebuchet", size=16, weight="bold")
entry2 = Text(ventana,font=Helvfont16, background="#10222F",height=1, width=61,foreground="#c0c0c0",bd=0)
entry2.insert(tk.INSERT, "Do you think you gonna save the planet by driving an electric car?")
entry2.place(x=300, y=130)

cars2018_c=pd.read_csv(r'C:\Users\Portu\Carsco2\cars.csv')
table_elec_source_breakdown=pd.read_csv(r'C:\Users\Portu\Carsco2\tableele.csv')
     
def open ():
    top=Toplevel()
    top.title("Time to choose")
    top.geometry("1200x600")
    top.configure(background= "#10222F")
    Helvfont20 = font.Font(family="Trebuchet", size=20, weight="bold")
    entry = Text(top,font=Helvfont20, background="#10222F",height=1, width=40,foreground="#c0c0c0",bd=0)
    entry.insert(tk.INSERT, "Welcome to the Co2 emission calculator")
    entry.place(x=180, y=60)
    Helvfont10 = font.Font(family="Trebuchet", size=10, weight="bold")
    texto = Text(top,font=Helvfont10,background="#10222F",height=3, width=122,foreground="#c0c0c0",bd=0)
    texto.insert(tk.INSERT, "Instructions: You can choose a maximum of three cars. First, choose a brand and automatically will load all the available models.       Once picked you have to choose a maximum of three countries and a place of driving. In case you don't choose,by default the country will be Portugal and driving place the mixed one (City- Highway). Have fun!")
    texto.place(x=180, y=150)
    
    brands = ['Acura','Alfa Romeo','Aston Martin','Audi','Bentley','Bmw','Bugatti','Buick','Cadillac','Chevrolet','Chrysler',
                 'Dodge','Ferrari','Fiat','Ford','Genesis','Honda','Hyundai','Infiniti','Jaguar','Jeep','Karma','Kia',
                 'Lamborghini','Land rover','Lexus','Lincoln','Lotus','Maserati','Mazda','Mclaren Automotive','Mercedes-Benz',
                 'Mini','Mitsubishi','Nissan','Pagani','Polestar','Porsche','Ram','Rolls-royce','Roush Performance','Ruf Automobile',
                 'Smart','Sti','Subaru','Tesla','Toyota','Volkswagen','Volvo']

    models =[['ILX', 'MDX AWD', 'MDX AWD A-SPEC', 'MDX FWD', 'MDX Hybrid AWD', 'NSX Hybrid', 'RDX AWD', 'RDX AWD A-SPEC', 'RDX FWD', 'RDX FWD A-SPEC', 'RLX', 'RLX Hybrid', 'TLX AWD', 'TLX AWD A-SPEC', 'TLX FWD', 'TLX FWD A-SPEC'], ['4C', 'Giulia', 'Giulia AWD', 'Stelvio', 'Stelvio AWD'], ['DB11 V12', 'DB11 V8', 'DBS', 'DBX V8', 'Rapide S', 'Vanquish S', 'Vantage Manual', 'Vantage V8'], ['A3', 'A3 Cabriolet', 'A3 Cabriolet quattro', 'A3 quattro', 'A4', 'A4 S line quattro', 'A4 allroad quattro', 'A4 quattro', 'A5 Cabriolet quattro', 'A5 Sportback S line quattro', 'A5 Sportback quattro', 'A5 quattro', 'A6 Allroad', 'A6 quattro', 'A7 quattro', 'A8 L', 'Q3 S-line quattro', 'Q3 quattro', 'Q5', 'Q7', 'Q8', 'R8', 'R8 2WD', 'R8 AWD', 'R8 Spyder', 'R8 Spyder 2WD', 'R8 Spyder AWD', 'RS 3', 'RS 5', 'RS 5 Sportback', 'RS 6 Avant', 'RS 7', 'RS Q8', 'RS3', 'S3', 'S4', 'S5', 'S5 Cabriolet', 'S5 Sportback', 'S6', 'S7', 'S8', 'SQ5', 'SQ7', 'SQ8', 'TT Coupe quattro', 'TT RS', 'TT Roadster quattro', 'TTS Coupe', 'e-tron', 'e-tron Sportback'], ['Bentayga', 'Continental GT', 'Continental GT Convertible', 'Flying Spur', 'Mulsanne'], ['228i xDrive Gran Coupe', '230i Convertible', '230i Coupe', '230i xDrive Convertible', '230i xDrive Coupe', '330e', '330e xDrive', '330i', '330i xDrive', '330i xDrive Gran Turismo', '330i xDrive Sports Wagon', '340i xDrive Gran Turismo', '430i Convertible', '430i Coupe', '430i Gran Coupe', '430i xDrive Convertible', '430i xDrive Coupe', '430i xDrive Gran Coupe', '440i Convertible', '440i Coupe', '440i Gran Coupe', '440i xDrive Convertible', '440i xDrive Coupe', '440i xDrive Gran Coupe', '530e', '530e xDrive', '530i', '530i xDrive', '540i', '540i xDrive', '640i Gran Coupe', '640i xDrive Gran Coupe', '640i xDrive Gran Turismo', '650i Gran Coupe', '650i xDrive Gran Coupe', '740e xDrive', '740i', '740i xDrive', '745e xDrive', '750i', '750i xDrive', '840i Convertible', '840i Coupe', '840i Gran Coupe', '840i xDrive Convertible', '840i xDrive Coupe', '840i xDrive Gran Coupe', 'Alpina B6 xDrive Gran Coupe', 'Alpina B7', 'Alpina B7 xDrive', 'Alpina XB7', 'I8 Coupe', 'I8 Roadster', 'M2 CS Coupe', 'M2 Competition', 'M2 Competition Coupe', 'M235i xDrive', 'M235i xDrive Gran Coupe', 'M240i Convertible', 'M240i Coupe', 'M240i Coupe M Performance', 'M240i xDrive Convertible', 'M240i xDrive Coupe', 'M240i xDrive Coupe M Performance', 'M340i', 'M340i xDrive', 'M4 CS', 'M4 Convertible', 'M4 Convertible Competition', 'M4 Coupe', 'M4 Coupe Competition', 'M440i xDrive Coupe', 'M5', 'M5 Competition', 'M550i xDrive', 'M6 Gran Coupe', 'M760i xDrive', 'M8 Competition Convertible', 'M8 Competition Coupe', 'M8 Competition Gran Coupe', 'M8 Convertible', 'M8 Coupe', 'M8 Gran Coupe', 'M850i xDrive Convertible', 'M850i xDrive Coupe', 'M850i xDrive Gran Coupe', 'X1 sDrive28i', 'X1 xDrive28i', 'X2 M35i', 'X2 sDrive28i', 'X2 xDrive28i', 'X3 M', 'X3 M Competition', 'X3 M40i', 'X3 sDrive30i', 'X3 xDrive30e', 'X3 xDrive30i', 'X4 M', 'X4 M Competition', 'X4 M40i', 'X4 xDrive30i', 'X5 M', 'X5 M Competition', 'X5 M50i', 'X5 sDrive40i', 'X5 xDrive40i', 'X5 xDrive45e', 'X5 xDrive50i', 'X6 M', 'X6 M Competition', 'X6 M50i', 'X6 sDrive35i', 'X6 sDrive40i', 'X6 xDrive35i', 'X6 xDrive40i', 'X6 xDrive50i', 'X7 M50i', 'X7 xDrive40i', 'X7 xDrive50i', 'Z4 M40i', 'Z4 sDrive30i', 'i3', 'i3 with Range Extender', 'i3s', 'i3s with Range Extender'], ['Chiron', 'Divo'], ['Cascada', 'Enclave AWD', 'Enclave FWD', 'Encore', 'Encore AWD', 'Encore FWD', 'Encore GX AWD', 'Encore GX FWD', 'Envision AWD', 'Envision FWD', 'LaCrosse', 'LaCrosse AWD', 'LaCrosse eAssist', 'Regal', 'Regal AWD', 'Regal TourX AWD'], ['ATS', 'ATS AWD', 'ATS-V', 'CT4', 'CT4 AWD', 'CT4 V', 'CT4 V AWD', 'CT5', 'CT5 AWD', 'CT5 V', 'CT5 V AWD', 'CT6', 'CT6 AWD', 'CTS', 'CTS AWD', 'CTS-V', 'Escalade 2WD', 'Escalade 4WD', 'XT4 AWD', 'XT4 FWD', 'XT5', 'XT5 AWD', 'XT5 FWD', 'XT5 Hearse AWD', 'XT5 Hearse FWD', 'XT6 AWD', 'XT6 FWD', 'XTS', 'XTS AWD', 'XTS Hearse', 'XTS Limo'], ['Blazer AWD', 'Blazer FWD', 'Bolt EV', 'Camaro', 'Colorado 2WD', 'Colorado 4WD', 'Colorado Cab Chassis 2WD', 'Colorado ZR2 4WD', 'Corvette', 'Corvette Z06', 'Corvette ZR1', 'Cruze', 'Cruze Hatchback', 'Cruze Premier', 'Cruze Premier Hatchback', 'Equinox AWD', 'Equinox FWD', 'Impala', 'Malibu', 'Malibu Hybrid', 'Silverado 2WD', 'Silverado 4WD', 'Silverado 4WD TrailBoss', 'Silverado C10 2WD', 'Silverado C10 Cab Chassis 2WD', 'Silverado C10 XFE 2WD', 'Silverado Cab Chassis 2WD', 'Silverado Cab Chassis 4WD', 'Silverado K10 4WD', 'Silverado K10 4WD TrailBoss', 'Silverado K10 Cab Chassis 4WD', 'Silverado LD C15 2WD', 'Silverado LD K15 4WD', 'Sonic', 'Sonic 5', 'Spark', 'Spark ACTIV', 'Suburban 2WD', 'Suburban 4WD', 'Suburban C1500 2WD', 'Suburban K1500 4WD', 'Tahoe 2WD', 'Tahoe 4WD', 'Tahoe C1500 2WD', 'Tahoe K1500 4WD', 'Trailblazer AWD', 'Trailblazer FWD', 'Traverse AWD', 'Traverse FWD', 'Trax', 'Trax AWD', 'Trax FWD', 'Volt'], ['300', '300 AWD', 'Pacifica', 'Pacifica AWD', 'Pacifica Hybrid', 'Voyager'], ['Challenger', 'Challenger AWD', 'Challenger GT', 'Challenger SRT', 'Challenger SRT Widebody', 'Challenger Widebody', 'Charger', 'Charger AWD', 'Charger SRT', 'Charger SRT Widebody', 'Charger Widebody', 'Durango AWD', 'Durango RWD', 'Durango SRT AWD', 'Grand Caravan', 'Journey', 'Journey AWD'], ['488 GTB', '488 Pista', '488 Pista Spider', '488 Spider', '812 GTS', '812 Superfast', 'F8 Spider', 'F8 Tributo', 'GTC4Lusso', 'GTC4Lusso T', 'Portofino', 'Portofino M', 'Roma', 'SF90 Stradale Coupe'], ['124 Spider', '500', '500 Abarth', '500 L', '500X AWD', '500e'], ['EcoSport AWD', 'EcoSport FWD', 'Edge AWD', 'Edge FWD', 'Escape AWD', 'Escape AWD HEV', 'Escape FWD', 'Escape FWD FFV', 'Escape FWD HEV', 'Escape FWD PHEV', 'Expedition 2WD', 'Expedition 4WD', 'Expedition MAX 2WD', 'Expedition MAX 4WD', 'Explorer 2WD FFV', 'Explorer AWD', 'Explorer AWD FFV', 'Explorer FFV AWD', 'Explorer FWD', 'Explorer HEV AWD', 'Explorer HEV RWD', 'Explorer RWD', 'F150 2.7L 2WD GVWR>6649 LBS', 'F150 2.7L 4WD GVWR>6799 LBS', 'F150 2WD BASE PAYLOAD LT TIRE', 'F150 2WD FFV BASE PAYLOAD LT', 'F150 3.5L 2WD GVWR>7599 LBS', 'F150 3.5L 4WD GVWR>7599 LBS', 'F150 4WD BASE PAYLOAD LT TIRE', 'F150 4WD FFV BASE PAYLOAD LT', 'F150 5.0L 2WD FFV GVWR>7599 LBS', 'F150 5.0L 4WD FFV GVWR>7599 LBS', 'F150 Pickup 2WD', 'F150 Pickup 2WD FFV', 'F150 Pickup 2WD Limited', 'F150 Pickup 4WD', 'F150 Pickup 4WD FFV', 'F150 Pickup 4WD Limited', 'F150 Pickup 4WD XL/XLT', 'F150 RAPTOR 4WD', 'Fiesta FWD', 'Fiesta ST FWD', 'Flex AWD', 'Flex FWD', 'Fusion AWD', 'Fusion Energi Plug-in Hybrid', 'Fusion FWD', 'Fusion Hybrid FWD', 'Fusion Hybrid Taxi', 'Fusion Special Service PHEV', 'Fusion Special Service Vehicle PHEV', 'GT', 'Mustang', 'Mustang Bullitt', 'Mustang Convertible', 'Mustang HO Convertible', 'Mustang HO Coupe', 'Mustang Performance Package', 'Ranger 2WD', 'Ranger 2WD Incomplete', 'Ranger 4WD', 'Shelby GT350 Mustang', 'Shelby GT500 Mustang', 'Taurus AWD', 'Taurus AWD FFV', 'Taurus FWD', 'Taurus FWD FFV', 'Transit Connect USPS', 'Transit Connect Van 2WD', 'Transit Connect Van FFV', 'Transit Connect Van FWD', 'Transit Connect Wagon LWB FFV', 'Transit Connect Wagon LWB FWD', 'Transit T150 Wagon', 'Transit T150 Wagon 2WD FFV', 'Transit T150 Wagon 4WD FFV', 'Transit T150 Wagon FFV'], ['G70 AWD', 'G70 RWD', 'G80 AWD', 'G80 RWD', 'G90 AWD', 'G90 RWD', 'GV80 AWD', 'GV80 RWD'], ['Accord', 'Accord 2.0T Sport/Touring', 'Accord Hybrid', 'Accord Hybrid Sport/Touring', 'Accord Sport/Touring', 'CR-V AWD', 'CR-V FWD', 'Civic 2Dr', 'Civic 4Dr', 'Civic 5Dr', 'Clarity EV', 'Clarity Plug-in Hybrid', 'Fit', 'HR-V AWD', 'HR-V FWD', 'Insight', 'Insight Touring', 'Odyssey', 'Passport AWD', 'Passport FWD', 'Pilot AWD', 'Pilot FWD', 'Ridgeline AWD', 'Ridgeline FWD'], ['Accent', 'Elantra', 'Elantra GT', 'Elantra SE', 'Ioniq', 'Ioniq Blue', 'Ioniq Electric', 'Ioniq Plug-in Hybrid', 'Kona AWD', 'Kona Electric', 'Kona FWD', 'Palisade AWD', 'Palisade FWD', 'Santa Fe AWD', 'Santa Fe FWD', 'Santa Fe XL AWD', 'Santa Fe XL FWD', 'Santa Fe XL Ultimate AWD', 'Santa Fe XL Ultimate FWD', 'Sonata', 'Sonata Hybrid', 'Sonata Hybrid Blue', 'Sonata Hybrid SE', 'Sonata Plug-in Hybrid', 'Sonata SE', 'Tucson AWD', 'Tucson FWD', 'Veloster', 'Veloster N', 'Venue'], ['Q50', 'Q50 AWD', 'Q50 Red Sport', 'Q50 Red Sport  AWD', 'Q60', 'Q60 AWD', 'Q60 Red Sport', 'Q60 Red Sport AWD', 'Q70', 'Q70 AWD', 'QX30', 'QX30 AWD', 'QX50', 'QX50 AWD', 'QX60 AWD', 'QX60 FWD', 'QX80 2WD', 'QX80 4WD'], ['E-Pace', 'E-Pace P250', 'E-Pace P300', 'F-Pace', 'F-Pace 30t', 'F-Type AWD Convertible', 'F-Type AWD Coupe', 'F-Type Convertible', 'F-Type Coupe', 'F-Type R AWD Convertible', 'F-Type R AWD Coupe', 'F-Type S AWD Convertible', 'F-Type S AWD Coupe', 'F-Type S Convertible', 'F-Type S Coupe', 'F-Type SVR AWD Convertible', 'F-Type SVR AWD Convertible GEN2', 'F-Type SVR AWD Coupe', 'F-Type SVR AWD Coupe GEN2', 'I-Pace', 'XE', 'XE 30t', 'XE AWD', 'XE AWD 30t', 'XF', 'XF 30t', 'XF AWD', 'XF AWD 30t', 'XF Sportbrake AWD', 'XJ', 'XJ AWD', 'XJL', 'XJL AWD'], ['Cherokee 4WD', 'Cherokee 4WD Active Drive II', 'Cherokee FWD', 'Cherokee Trailhawk 4WD', 'Compass 4WD', 'Compass FWD', 'Gladiator 4WD', 'Gladiator EcoDiesel 4WD', 'Gladiator Pickup 4WD', 'Gladiator Rubicon EcoDiesel 4WD', 'Grand Cherokee 2WD', 'Grand Cherokee 4WD', 'Grand Cherokee SRT 4WD', 'Grand Cherokee Trackhawk 4WD', 'Renegade 2WD', 'Renegade 4WD', 'Renegade Trailhawk 4WD', 'Wrangler 2dr 4WD', 'Wrangler 4WD', 'Wrangler 4dr 4WD', 'Wrangler 4dr EcoDiesel 4WD', 'Wrangler Rubic 4dr EcoDiesel 4WD', 'Wrangler Unlimited 4WD'], ['Revero', 'Revero GT (21-inch wheels)'], ['Cadenza', 'Forte', 'Forte FE', 'K5', 'K5 AWD', 'K900', 'Niro', 'Niro Electric', 'Niro FE', 'Niro Plug-in Hybrid', 'Niro Touring', 'Optima', 'Optima FE', 'Optima Hybrid', 'Optima Plug-in Hybrid', 'Rio', 'Sedona', 'Seltos AWD', 'Seltos FWD', 'Sorento AWD', 'Sorento FWD', 'Sorento Hybrid', 'Soul', 'Soul Eco dynamics', 'Soul Electric', 'Sportage AWD', 'Sportage FE AWD', 'Sportage FE FWD', 'Sportage FWD', 'Stinger AWD', 'Stinger RWD', 'Telluride AWD', 'Telluride FWD'], ['Aventador Coupe', 'Aventador Roadster', 'Aventador Sian Coupe', 'Aventador Sian Roadster', 'Huracan', 'Huracan 2WD', 'Huracan Spyder', 'Huracan Spyder 2WD', 'Urus'], ['Defender 110', 'Defender 110 MHEV', 'Defender 90', 'Defender 90 MHEV', 'Discovery', 'Discovery Sport', 'Discovery Sport MHEV', 'Discovery Sport Si4', 'Evoque', 'Evoque MHEV', 'Range Rover', 'Range Rover Evoque 237HP', 'Range Rover Evoque 286HP', 'Range Rover Evoque Cabriolet', 'Range Rover LWB', 'Range Rover LWB SVA', 'Range Rover MHEV', 'Range Rover PHEV', 'Range Rover SV Coupe', 'Range Rover SVA', 'Range Rover Sport', 'Range Rover Sport MHEV', 'Range Rover Sport PHEV', 'Range Rover Sport SVR', 'Range Rover Velar', 'Range Rover Velar P300', 'Range Rover Velar P380'], ['ES 250 AWD', 'ES 300h', 'ES 350', 'ES 350 F Sport', 'GS 300', 'GS 300 F Sport', 'GS 350', 'GS 350 AWD', 'GS 350 F Sport', 'GS F', 'GX 460', 'IS 300', 'IS 300 AWD', 'IS 350', 'IS 350 AWD', 'LC 500', 'LC 500 Convertible', 'LC 500h', 'LS 500', 'LS 500 AWD', 'LS 500h', 'LS 500h AWD', 'LX 570', 'NX 300', 'NX 300 AWD', 'NX 300 AWD F Sport', 'NX 300h AWD', 'RC 300', 'RC 300 AWD', 'RC 350', 'RC 350 AWD', 'RC F', 'RX 350', 'RX 350 AWD', 'RX 350 L', 'RX 350 L AWD', 'RX 450h AWD', 'RX 450h L AWD', 'UX 200', 'UX 250h', 'UX 250h AWD'], ['Aviator AWD', 'Aviator PHEV AWD', 'Aviator RWD', 'Continental  AWD', 'Continental  FWD', 'Continental Coach', 'Corsair AWD', 'Corsair FWD', 'MKC AWD', 'MKC FWD', 'MKT AWD', 'MKT FWD', 'MKT Hearse AWD', 'MKT Limo AWD', 'MKT Livery AWD', 'MKZ AWD', 'MKZ FWD', 'MKZ Hybrid FWD', 'Nautilus AWD', 'Nautilus FWD', 'Navigator 2WD', 'Navigator 4WD', 'Navigator L 2WD'], ['Evora', 'Evora GT'], ['Ghibli', 'Ghibli  S RWD', 'Ghibli  V6 RWD', 'Ghibli S', 'Ghibli SQ4', 'Ghibli Trofeo', 'Ghibli V6 SQ4 AWD', 'GranTurismo Convertible', 'Levante', 'Levante GTS', 'Levante S', 'Levante Trofeo', 'Quattroporte GTS', 'Quattroporte S', 'Quattroporte SQ4', 'Quattroporte SQ4 V6', 'Quattroporte Trofeo', 'Quattroporte V8'], ['2', '3 4-Door 2WD', '3 4-Door 4WD', '3 5-Door 2WD', '3 5-Door 4WD', '6', 'CX-3 2WD', 'CX-3 4WD', 'CX-30 2WD', 'CX-30 4WD', 'CX-5 2WD', 'CX-5 4WD', 'CX-9 2WD', 'CX-9 4WD', 'MX-5'], ['570GT', '570S Coupe', '570S Spider', '600LT Coupe', '600LT Spider', '620R Coupe', '720S Coupe', '720S Spider', 'GT', 'Senna', 'Speedtail'], ['A220', 'A220 4matic', 'AMG A35 4matic', 'AMG C43 4matic', 'AMG C43 4matic Convertible', 'AMG C43 4matic Coupe', 'AMG C63', 'AMG C63 Convertible', 'AMG C63 Coupe', 'AMG C63 S', 'AMG C63 S Convertible', 'AMG C63 S Coupe', 'AMG CLA35 4matic', 'AMG CLA45 4matic', 'AMG CLS53 4matic Plus', 'AMG E53 4matic Plus', 'AMG E53 4matic Plus Convertible', 'AMG E53 4matic Plus Coupe', 'AMG E63 S 4matic', 'AMG E63 S 4matic (wagon)', 'AMG E63 S 4matic Plus', 'AMG E63 S 4matic Plus (wagon)', 'AMG G63', 'AMG GLA35 4matic', 'AMG GLA45 4matic', 'AMG GLC43 4matic', 'AMG GLC43 4matic Coupe', 'AMG GLC63 4matic', 'AMG GLC63 4matic Coupe', 'AMG GLC63 4matic Plus', 'AMG GLC63 4matic Plus Coupe', 'AMG GLC63 S 4matic Coupe', 'AMG GLC63 S 4matic Plus Coupe', 'AMG GLE43 4matic', 'AMG GLE43 4matic Coupe', 'AMG GLE53 4matic Plus', 'AMG GLE53 4matic Plus Coupe', 'AMG GLE63', 'AMG GLE63 S', 'AMG GLE63 S 4matic Plus', 'AMG GLE63 S Coupe', 'AMG GLS63', 'AMG GLS63 4matic Plus', 'AMG GT 43 4matic Plus', 'AMG GT 53 4matic Plus', 'AMG GT 63 4matic Plus', 'AMG GT 63 S 4matic Plus', 'AMG GT C Coupe', 'AMG GT C Roadster', 'AMG GT Coupe', 'AMG GT R Coupe', 'AMG GT R Roadster', 'AMG GT Roadster', 'AMG GT S Coupe', 'AMG S63 4matic', 'AMG S63 4matic Convertible', 'AMG S63 4matic Coupe', 'AMG S63 4matic Plus', 'AMG S63 4matic Plus Convertible', 'AMG S63 4matic Plus Coupe', 'AMG S65', 'AMG S65 Convertible', 'AMG S65 Coupe', 'AMG SL63', 'AMG SLC43', 'C300', 'C300 4matic', 'C300 4matic Convertible', 'C300 4matic Coupe', 'C300 Convertible', 'C300 Coupe', 'CLA250', 'CLA250 4matic', 'CLS450', 'CLS450 4matic', 'E300', 'E300 4matic', 'E350', 'E350 4matic', 'E450 4matic', 'E450 4matic (station wagon)', 'E450 4matic All-Terrain (wagon)', 'E450 4matic Convertible', 'E450 4matic Coupe', 'E450 Convertible', 'E450 Coupe', 'G550', 'GLA250', 'GLA250 4matic', 'GLB250', 'GLB250 4matic', 'GLC300', 'GLC300 4matic', 'GLC300 4matic Coupe', 'GLC350e 4matic', 'GLE350', 'GLE350 4matic', 'GLE400 4matic', 'GLE450 4matic', 'GLE580 4matic', 'GLS450 4matic', 'GLS550 4matic', 'GLS580 4matic', 'Maybach S560 4matic', 'Maybach S650', 'Metris (Cargo Van)', 'Metris (Cargo Van, LWB)', 'Metris (Passenger Van)', 'S450', 'S450 4matic', 'S560', 'S560 4matic', 'S560 4matic Coupe', 'S560 4matic Maybach', 'S560 Convertible', 'S560e', 'SL450', 'SL550', 'SLC300'], ['Cooper Clubman', 'Cooper Clubman All4', 'Cooper Convertible', 'Cooper Countryman', 'Cooper Countryman All4', 'Cooper Hardtop 2 door', 'Cooper Hardtop 4 door', 'Cooper S Clubman', 'Cooper S Clubman All4', 'Cooper S Convertible', 'Cooper S Countryman', 'Cooper S Countryman All4', 'Cooper S Hardtop 2 door', 'Cooper S Hardtop 4 door', 'Cooper SE Countryman All4', 'Cooper SE Hardtop 2 door', 'JCW Countryman All4', 'John Cooper Works Clubman All4', 'John Cooper Works Convertible', 'John Cooper Works GP', 'John Cooper Works Hardtop'], ['Eclipse Cross 2WD', 'Eclipse Cross 4WD', 'Eclipse Cross ES 2WD', 'Eclipse Cross ES 4WD', 'Mirage', 'Mirage G4', 'Outlander 2WD', 'Outlander 4WD', 'Outlander PHEV', 'Outlander Sport 2WD', 'Outlander Sport 4WD'], ['370Z', '370Z Roadster', 'Altima', 'Altima AWD', 'Altima AWD SR/Platinum', 'Altima SR', 'Altima SR/Platinum', 'Altima SV/SL', 'Armada 2WD', 'Armada 4WD', 'Frontier 2WD', 'Frontier 2WD FFV', 'Frontier 4WD', 'Frontier 4WD FFV', 'GT-R', 'Kicks', 'Leaf (40 kW-hr battery pack)', 'Leaf (62 kW-hr battery pack)', 'Leaf SV/SL (62 kW-hr battery pack)', 'Maxima', 'Murano AWD', 'Murano FWD', 'NV200 Cargo Van', 'NV200 NYC Taxi', 'Pathfinder 2WD', 'Pathfinder 4WD', 'Pathfinder 4WD Platinum', 'Rogue AWD', 'Rogue AWD  SV/SL/Platinum', 'Rogue FWD', 'Rogue FWD  SV/SL/Platinum', 'Rogue Hybrid  AWD', 'Rogue Hybrid  FWD', 'Rogue Sport', 'Rogue Sport AWD', 'Sentra', 'Sentra Nismo', 'Sentra SR', 'Titan 2WD', 'Titan 4WD', 'Titan 4WD PRO-4X', 'Titan 4WD PRO4X', 'Versa'], ['Huayra Roadster BC'], ['1', '2'], ['718 Cayman GT4', '718 Spyder', '911 Carrera', '911 Carrera 4', '911 Carrera 4 Cabriolet', '911 Carrera 4 GTS', '911 Carrera 4 GTS Cabriolet', '911 Carrera 4S', '911 Carrera 4S Cabriolet', '911 Carrera Cabriolet', '911 Carrera GTS', '911 Carrera GTS Cabriolet', '911 Carrera S', '911 Carrera S Cabriolet', '911 Carrera T', '911 GT2 RS', '911 GT3', '911 GT3 RS', '911 GT3 Touring', '911 Speedster', '911 Targa 4', '911 Targa 4 GTS', '911 Targa 4S', '911 Turbo', '911 Turbo Cabriolet', '911 Turbo S', '911 Turbo S Cabriolet', '911 Turbo S Exclusive Cabriolet', 'Boxster', 'Boxster GTS', 'Boxster S', 'Boxster T', 'Cayenne', 'Cayenne Coupe', 'Cayenne GTS', 'Cayenne GTS Coupe', 'Cayenne S', 'Cayenne S Coupe', 'Cayenne Turbo', 'Cayenne Turbo Coupe', 'Cayenne Turbo S e-Hybrid', 'Cayenne Turbo S e-Hybrid Coupe', 'Cayenne e-Hybrid', 'Cayenne e-Hybrid Coupe', 'Cayman', 'Cayman GTS', 'Cayman S', 'Cayman T', 'Macan', 'Macan GTS', 'Macan S', 'Macan Turbo', 'Panamera', 'Panamera 4', 'Panamera 4 Executive', 'Panamera 4 ST', 'Panamera 4 e-Hybrid', 'Panamera 4 e-Hybrid Executive', 'Panamera 4 e-Hybrid ST', 'Panamera 4S', 'Panamera 4S Executive', 'Panamera 4S ST', 'Panamera GTS', 'Panamera GTS ST', 'Panamera Turbo', 'Panamera Turbo Exec', 'Panamera Turbo Executive', 'Panamera Turbo S e-Hybrid', 'Panamera Turbo S e-Hybrid Executive', 'Panamera Turbo S e-Hybrid ST', 'Panamera Turbo ST', 'Taycan 4S Perf Battery Plus', 'Taycan Turbo', 'Taycan Turbo S'], ['1500 2WD', '1500 4WD', '1500 Classic 2WD', '1500 Classic 4WD', '1500 HFE 2WD', 'Promaster City'], ['Cullinan', 'Cullinan Black Badge', 'Dawn', 'Dawn Black Badge', 'Ghost', 'Ghost EWB', 'Phantom', 'Phantom EWB', 'Wraith', 'Wraith Black Badge'], ['F150 Pickup 2WD', 'F150 Pickup 4WD', 'Stage 3 Mustang'], ['RUFTURBO12/CTR3/CTR2017', 'TURBO12/CTR3/CTR ANNIVERSARY'], ['EQ fortwo (convertible)', 'EQ fortwo (coupe)'], ['S209'], ['Ascent', 'Ascent Limited/Touring', 'BRZ', 'BRZ tS', 'Crosstrek AWD', 'Crosstrek Hybrid AWD', 'Forester AWD', 'Impreza 4-Door', 'Impreza 5-Door', 'Impreza Sport 4-Door', 'Impreza Sport 5-Door', 'Legacy AWD', 'Outback AWD', 'WRX'], ['Model 3 Long Range', 'Model 3 Long Range AWD', 'Model 3 Long Range AWD Performance', 'Model 3 Long Range Performance AWD (18in)', 'Model 3 Long Range Performance AWD (19in)', 'Model 3 Long Range Performance AWD (20in)', 'Model 3 Mid Range', 'Model 3 Performance AWD', 'Model 3 Standard Range', 'Model 3 Standard Range Plus', 'Model S 100D', 'Model S 75D', 'Model S Long Range', 'Model S Long Range Plus', 'Model S P100D', 'Model S Performance (19in Wheels)', 'Model S Performance (21in Wheels)', 'Model S Standard Range', 'Model X 100D', 'Model X 75D', 'Model X Long Range', 'Model X Long Range Plus', 'Model X P100D', 'Model X Performance (20in Wheels)', 'Model X Performance (22in Wheels)', 'Model X Standard Range', 'Model Y Long Range AWD', 'Model Y Performance AWD', 'Model Y Performance AWD (21in Wheels)'], ['4Runner 2WD', '4Runner 4WD', '86', 'Avalon', 'Avalon AWD', 'Avalon Hybrid', 'Avalon Hybrid XLE', 'Avalon TRD', 'Avalon XLE', 'C-HR', 'Camry', 'Camry AWD LE/SE', 'Camry AWD XLE/XSE', 'Camry Hybrid LE', 'Camry Hybrid SE/XLE/XSE', 'Camry Hybrid XLE/SE', 'Camry LE/SE', 'Camry TRD', 'Camry XLE/XSE', 'Camry XSE', 'Corolla', 'Corolla APEX', 'Corolla Hatchback', 'Corolla Hatchback XSE', 'Corolla Hybrid', 'Corolla LE Eco', 'Corolla XLE', 'Corolla XSE', 'GR Supra', 'Highlander', 'Highlander AWD', 'Highlander AWD LE', 'Highlander Hybrid', 'Highlander Hybrid AWD', 'Highlander Hybrid AWD LE Plus', 'Highlander Hybrid AWD LTD/PLAT', 'Highlander LE/XLE/SE/LTD', 'Land Cruiser Wagon 4WD', 'Prius', 'Prius AWD', 'Prius Eco', 'Prius Prime', 'Prius c', 'RAV4', 'RAV4 AWD', 'RAV4 AWD LE', 'RAV4 AWD TRD OFFROAD', 'RAV4 Hybrid  AWD', 'RAV4 Hybrid AWD', 'RAV4 Prime 4WD', 'Sequoia 2WD', 'Sequoia 4WD', 'Sienna 2WD', 'Sienna AWD', 'Tacoma 2WD', 'Tacoma 4WD', 'Tacoma 4WD D-CAB MT TRD-ORP/PRO', 'Tacoma 4WD Double Cab Off-Road', 'Tacoma 4WD TRD PRO', 'Tundra 2WD', 'Tundra 4WD', 'Tundra 4WD FFV', 'Venza AWD', 'Yaris'], ['Arteon', 'Arteon 4motion', 'Atlas', 'Atlas 4motion', 'Atlas Cross Sport', 'Atlas Cross Sport 4motion', 'Beetle', 'Beetle Convertible', 'GTI', 'Golf', 'Golf Alltrack', 'Golf R', 'Golf SportWagen', 'Golf SportWagen 4motion', 'Jetta', 'Jetta GLI', 'Passat', 'Tiguan', 'Tiguan 4motion', 'e-Golf'], ['S60 AWD', 'S60 AWD PHEV', 'S60 FWD', 'S90 AWD', 'S90 AWD PHEV', 'S90 FWD', 'V60 AWD', 'V60 AWD PHEV', 'V60 CC AWD', 'V60 FWD', 'V90 AWD', 'V90 CC AWD', 'V90 FWD', 'XC40 AWD', 'XC40 AWD BEV', 'XC40 FWD', 'XC60 AWD', 'XC60 AWD PHEV', 'XC60 FWD', 'XC90 AWD', 'XC90 AWD PHEV', 'XC90 FWD']]
    
    country=['Afghanistan','Albania','Algeria','American Samoa','Andorra','Angola','Antigua and Barbuda','Argentina','Armenia','Aruba','Australia','Austria','Azerbaijan','Bahamas, The','Bahrain','Bangladesh','Barbados','Belarus','Belgium','Belize','Benin','Bermuda','Bhutan','Bolivia','Bosnia and Herzegovina','Botswana','Brazil','British Virgin Islands','Brunei Darussalam','Bulgaria','Burkina Faso','Burundi','Cabo Verde','Cambodia','Cameroon','Canada','Cayman Islands','Central African Republic','Chad','Channel Islands','Chile','China','Colombia','Comoros','Congo, Dem. Rep.','Congo, Rep.','Costa Rica',"Cote d'Ivoire",'Croatia','Cuba','Curacao','Cyprus','Czech Republic','Denmark','Djibouti','Dominica','Dominican Republic','Ecuador','Egypt, Arab Rep.','El Salvador','Equatorial Guinea','Eritrea','Estonia','Eswatini','Ethiopia','Faroe Islands','Fiji','Finland','France','French Polynesia','Gabon','Gambia, The','Georgia','Germany','Ghana','Gibraltar','Greece','Greenland','Grenada','Guam','Guatemala','Guinea','Guinea-Bissau','Guyana','Haiti','Honduras','Hong Kong SAR, China','Hungary','Iceland','India','Indonesia','Iran, Islamic Rep.','Iraq','Ireland','Isle of Man','Israel','Italy','Jamaica','Japan','Jordan','Kazakhstan','Kenya','Kiribati','Korea, Dem. People’s Rep.','Korea, Rep.','Kosovo','Kuwait','Kyrgyz Republic','Lao PDR','Latvia','Lebanon','Lesotho','Liberia','Libya','Liechtenstein','Lithuania','Luxembourg','Macao SAR, China','Madagascar','Malawi','Malaysia','Maldives','Mali','Malta','Marshall Islands','Mauritania','Mauritius','Mexico','Micronesia, Fed. Sts.','Moldova','Monaco','Mongolia','Montenegro','Morocco','Mozambique','Myanmar','Namibia','Nauru','Nepal','Netherlands','New Caledonia','New Zealand','Nicaragua','Niger','Nigeria','North Macedonia','Northern Mariana Islands','Norway','Oman','Pakistan','Palau','Panama','Papua New Guinea','Paraguay','Peru','Philippines','Poland','Portugal','Puerto Rico','Qatar','Romania','Russian Federation','Rwanda','Samoa','San Marino','Sao Tome and Principe','Saudi Arabia','Senegal','Serbia','Seychelles','Sierra Leone','Singapore','Sint Maarten (Dutch part)','Slovak Republic','Slovenia','Solomon Islands','Somalia','South Africa','South Sudan','Spain','Sri Lanka','St. Kitts and Nevis','St. Lucia','St. Martin (French part)','St. Vincent and the Grenadines','Sudan','Suriname','Sweden','Switzerland','Syrian Arab Republic','Tajikistan','Tanzania','Thailand','Timor-Leste','Togo','Tonga','Trinidad and Tobago','Tunisia','Turkey','Turkmenistan','Turks and Caicos Islands','Tuvalu','Uganda','Ukraine','United Arab Emirates','United Kingdom','United States','Uruguay','Uzbekistan','Vanuatu','Venezuela, RB','Vietnam','Virgin Islands (U.S.)','West Bank and Gaza','Yemen, Rep.','Zambia','Zimbabwe']
    
    drivinghabit=["City","Highway","Both"]
    
    car_brand = ttk.Combobox(top, width=37,state="readonly", value=(brands))
    car_brand.place(x=150, y =250)

    def callback(eventObject):
        global car
        abc = eventObject.widget.get()
        car = car_brand.get()
        index=brands.index(car)
        car_model.config(values=models[index])
        
    def combo1(event):
        global car_modelb
        car_modelb=car_model.get()
        
        car_choice1 = car +' '+ car_modelb
        car_picks.append(car_choice1)
        
    car_model = ttk.Combobox(top,state="readonly", width=37)
    car_model.place(x=150, y= 300)
    car_model.bind('<Button-1>',callback)
    car_model.bind('<<ComboboxSelected>>',combo1)
    

    car_brand2 = ttk.Combobox(top, width=37,state="readonly", value=(brands))
    car_brand2.place(x=500, y =250)

    def callback2(eventObject):
        global car2
        abc = eventObject.widget.get()
        car2 = car_brand2.get()
        index2=brands.index(car2)
        car_model2.config(values=models[index2])
        
    def combo2(event):
        global car_model2b
        car_model2b=car_model2.get()
        
        car_choice2 = car2 +' '+ car_model2b
        car_picks.append(car_choice2)

    car_model2 = ttk.Combobox(top, state="readonly", width=37)
    car_model2.place(x=500, y =300)
    car_model2.bind('<Button-1>', callback2)
    car_model2.bind('<<ComboboxSelected>>',combo2)

    car_brand3 = ttk.Combobox(top, width=37, state="readonly", value=(brands))
    car_brand3.place(x=800, y =250)

    def callback3(eventObject):
        global car3
        abc = eventObject.widget.get()
        car3 = car_brand3.get()
        index3=brands.index(car3)
        car_model3.config(values=models[index3])
        
    def combo3(event):
        global car_model3b
        car_model3b=car_model3.get()
        
        car_choice3 = car3 +' '+ car_model3b
        car_picks.append(car_choice3)
        #print(car_picks)
        
    car_model3 = ttk.Combobox(top,state="readonly", width=37)
    car_model3.place(x=800, y =300)
    car_model3.bind('<Button-1>', callback3)
    car_model3.bind('<<ComboboxSelected>>',combo3)
    
    def pais(event):
        countrychoice=countrycombo.get()
        country_picks.append(countrychoice)
        
    countrycombo = ttk.Combobox(top,state="readonly", value=(country))
    countrycombo.place(x=200, y =350)
    countrycombo.bind('<<ComboboxSelected>>',pais)
    
    def pais2(event):
        countrychoice2=countrycombo2.get()
        country_picks.append(countrychoice2)
    
    countrycombo2 = ttk.Combobox(top,state="readonly", value=(country))
    countrycombo2.place(x=550, y =350)
    countrycombo2.bind('<<ComboboxSelected>>',pais2)
    
    def pais3(event):
        countrychoice3=countrycombo3.get()
        country_picks.append(countrychoice3)
        #print(country_picks)
            
    countrycombo3 = ttk.Combobox(top, state="readonly", value=(country))
    countrycombo3.place(x=850, y =350)
    countrycombo3.bind('<<ComboboxSelected>>',pais3)
    
    def habito(event):
            habitoconduccion=drhabit.get()
            habit_list.append(habitoconduccion)
        #print(habit_list) 
    
    drhabit = ttk.Combobox(top,state="readonly", value=(drivinghabit))
    drhabit.place(x=550, y =400)
    drhabit.bind('<<ComboboxSelected>>',habito)
    
    def final():
        if len (habit_list)<1:
            habit_list. append("Both")
        if len(country_picks)<1:
            country_picks.append("Portugal")
        top2=Toplevel()
        top2.title("Your Choice:Co2 grams emission")
        top2.geometry("1200x600")
        frame = tk.Frame(top2)
        frame.pack(fill='both', expand=True)
        
        print(country_picks)
        print(car_picks)
        print(habit_list)
        dict_car={}
        for model in car_picks:
            co2values= []
            for country in country_picks:
                if cars2018_c["fuelType"][cars2018_c["model_full"]==model].iloc[0] != "Electricity":
                    co2emission=(cars2018_c["co2_per_km"][cars2018_c["model_full"]==model]).mean() 
                    co2values.append(co2emission)
                else :
                    oil_source = table_elec_source_breakdown[table_elec_source_breakdown["Country"]==country]["Oil Sources %"].iloc[0]/100
                    nuclear_source = table_elec_source_breakdown[table_elec_source_breakdown["Country"]==country]["Nuclear Sources %"].iloc[0]/100
                    coal_source = table_elec_source_breakdown[table_elec_source_breakdown["Country"]==country]["Coal Sources %"].iloc[0]/100
                    naturalgas_source = table_elec_source_breakdown[table_elec_source_breakdown["Country"]==country]["Natural Gas Sources %"].iloc[0]/100
                    Hydro_source = table_elec_source_breakdown[table_elec_source_breakdown["Country"]==country]["Hydroelectric Sources %"].iloc[0]/100
                    Renew_source = table_elec_source_breakdown[table_elec_source_breakdown["Country"]==country]["Renewable Sources %"].iloc[0]/100
                    rest_source = table_elec_source_breakdown[table_elec_source_breakdown["Country"]==country]["rest"].iloc[0]/100
                        
                    if habit_list[0] == "City":
                            kwhperkm= (cars2018_c["cityE_100km"][cars2018_c["model_full"]==model]/100).mean()
                        
                            co2emission_elec = kwhperkm*coal_source*coal_prod + kwhperkm*oil_source*oil_prod + kwhperkm*nuclear_prod*nuclear_source + kwhperkm*natural_gas_prod*naturalgas_source + kwhperkm*renewable_prod*Renew_source +kwhperkm*hydroelectric_prod*Hydro_source
                            
                            co2emission_elec += rest_source*co2emission_elec
                            
                            co2emission_elec_inclbatt=co2emission_elec + 52 #calculation explained in documents attached: battery co2
                            
                            co2values.append(co2emission_elec_inclbatt)
                
                            
                    if habit_list[0] == "Highway":
                            kwhperkm= (cars2018_c["highwayE_per_km"][cars2018_c["model_full"]==model]/100).mean()
                            co2emission_elec = kwhperkm*coal_source*coal_prod + kwhperkm*oil_source*oil_prod + kwhperkm*nuclear_prod*nuclear_source + kwhperkm*natural_gas_prod*naturalgas_source + kwhperkm*renewable_prod*Renew_source +kwhperkm*hydroelectric_prod*Hydro_source
                            co2emission_elec += rest_source*co2emission_elec
                            co2emission_elec_inclbatt=co2emission_elec + 52
                            co2values.append(co2emission_elec_inclbatt)
                    
                            
                    if habit_list[0] == "Both":
                            kwhperkm= (cars2018_c["combE_per_km"][cars2018_c["model_full"]==model]/100).mean()
                            co2emission_elec = kwhperkm*coal_source*coal_prod + kwhperkm*oil_source*oil_prod + kwhperkm*nuclear_prod*nuclear_source + kwhperkm*natural_gas_prod*naturalgas_source + kwhperkm*renewable_prod*Renew_source +kwhperkm*hydroelectric_prod*Hydro_source
                            co2emission_elec += rest_source*co2emission_elec
                            co2emission_elec_inclbatt=co2emission_elec + 52
                            co2values.append(co2emission_elec_inclbatt)
                            
            dict_car[model] = co2values
        
        dict_car = pd.DataFrame.from_dict(dict_car).T
        dict_car.columns=country_picks
        dict_car["Choosen cars"]=dict_car.index
        display(dict_car)

        pt = Table(frame, dataframe=dict_car, showtoolbar=True, showstatusbar=True)
        pt.show()

            
    boton_salirtop=Button(top,font=Helvfont12,text="Leave me go!", command= ventana.destroy,background="#c0c0c0",foreground="#10222F",anchor="center")
    boton_salirtop.place(x=600,y=480)
    
    Helvfont20 = font.Font(family="Trebuchet", size=20, weight="bold")
    boton2=Button(top,text="Calculate!",font=Helvfont20,padx=10, pady=10, command=final, background="#c0c0c0",foreground="#10222F",anchor="center")
    boton2.place(x=370,y=480)
    
Helvfont12 = font.Font(family="Trebuchet", size=24, weight="bold")
boton=Button(font=Helvfont12,text="Let's find out!",padx=10, pady=10, command=open, background="#c0c0c0",foreground="#10222F",anchor="center")
boton.place(x=430,y=300)

#Close the main window
Helvfont12 = font.Font(family="Trebuchet", size=12, weight="bold")
boton_salir=Button(ventana,font=Helvfont12,text="Leave me go!", command= ventana.destroy,background="#c0c0c0",foreground="#10222F",anchor="center")
boton_salir.place(x=500,y=400)
    
ventana.mainloop()
